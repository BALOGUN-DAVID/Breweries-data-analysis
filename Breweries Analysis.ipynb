# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
breweries_data = "./breweries.csv"
breweries_data = pd.read_csv(breweries_data)
breweries_data
# Out:
#       SALES_ID SALES_REP               EMAILS       BRANDS  PLANT_COST  \
# 0        10101   Jardine       jard@gmail.com       trophy         150
# 1        10102      Gill      gillhell@uk.com    budweiser         250
# 2        10103   Sorvino  sorvi2000@gmail.com  castle lite         180
# 3        10104     Jones    jone.ai@yahoo.com  eagle lager         170
# 4        10105   Andrews       andy@gmail.com         hero         150
# ...        ...       ...                  ...          ...         ...
# 1042     11143   Jardine       jard@gmail.com   grand malt          90
# 1043     11144   Jardine       jard@gmail.com       trophy         150
# 1044     11145   Andrews       andy@gmail.com    budweiser         250
# 1045     11146     Jones    jone.ai@yahoo.com  castle lite         180
# 1046     11147    Morgan   morganny@gmail.com  eagle lager         170
#
#       UNIT_PRICE  QUANTITY   COSTS  PROFIT COUNTRIES        REGION     MONTHS  \
# ...

# %%
breweries_data.head()
# Out:
#    SALES_ID SALES_REP               EMAILS       BRANDS  PLANT_COST  \
# 0     10101   Jardine       jard@gmail.com       trophy         150
# 1     10102      Gill      gillhell@uk.com    budweiser         250
# 2     10103   Sorvino  sorvi2000@gmail.com  castle lite         180
# 3     10104     Jones    jone.ai@yahoo.com  eagle lager         170
# 4     10105   Andrews       andy@gmail.com         hero         150
#
#    UNIT_PRICE  QUANTITY   COSTS  PROFIT COUNTRIES     REGION     MONTHS  YEARS
# 0         200       725  145000   36250     Ghana   Southeast   January   2019
# 1         500       815  407500  203750   Nigeria        west  February   2018
# 2         450       937  421650  252990      Togo  southsouth     March   2018
# 3         250       765  191250   61200     Benin   northwest     April   2018
# 4         200       836  167200   41800   Senegal  northeast        May   2017

# %%
breweries_data.tail()
# Out:
#       SALES_ID SALES_REP              EMAILS       BRANDS  PLANT_COST  \
# 1042     11143   Jardine      jard@gmail.com   grand malt          90
# 1043     11144   Jardine      jard@gmail.com       trophy         150
# 1044     11145   Andrews      andy@gmail.com    budweiser         250
# 1045     11146     Jones   jone.ai@yahoo.com  castle lite         180
# 1046     11147    Morgan  morganny@gmail.com  eagle lager         170
#
#       UNIT_PRICE  QUANTITY   COSTS  PROFIT COUNTRIES        REGION     MONTHS  \
# 1042         150       962  144300   57720      Togo     northeast   November
# 1043         200       892  178400   44600     Benin  northcentral   December
# 1044         500       816  408000  204000   Senegal      Southeast   January
# 1045         450       939  422550  253530     Ghana           west  February
# 1046         250       935  233750   74800   Nigeria     southsouth     March
#
#       YEARS
# 1042   2017
# 1043   2017
# 1044   2019
# 1045   2017
# ...

# %%
breweries_data.shape
# Out:
# (1047, 13)

# %%
breweries_data.describe()
# Out:
#            SALES_ID   PLANT_COST   UNIT_PRICE     QUANTITY          COSTS  \
# count   1047.000000  1047.000000  1047.000000  1047.000000    1047.000000
# mean   10624.000000   152.989494   271.728749   850.737345  231034.049666
# std      302.387169    53.125477   133.378553    86.991652  115658.626612
# min    10101.000000    80.000000   150.000000   700.000000  105300.000000
# 25%    10362.500000    90.000000   150.000000   776.000000  141425.000000
# 50%    10624.000000   150.000000   200.000000   853.000000  184400.000000
# 75%    10885.500000   180.000000   450.000000   927.000000  351450.000000
# max    11147.000000   250.000000   500.000000  1000.000000  499500.000000
#
#               PROFIT        YEARS
# count    1047.000000  1047.000000
# mean   100847.583572  2017.941738
# std     77581.775930     0.808325
# min     35000.000000  2017.000000
# 25%     46880.000000  2017.000000
# 50%     58080.000000  2018.000000
# 75%    191205.000000  2019.000000
# ...

# %%
breweries_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1047 entries, 0 to 1046
# Data columns (total 13 columns):
# SALES_ID      1047 non-null int64
# SALES_REP     1047 non-null object
# EMAILS        1047 non-null object
# BRANDS        1047 non-null object
# PLANT_COST    1047 non-null int64
# UNIT_PRICE    1047 non-null int64
# QUANTITY      1047 non-null int64
# COSTS         1047 non-null int64
# PROFIT        1047 non-null int64
# COUNTRIES     1047 non-null object
# REGION        1047 non-null object
# MONTHS        1047 non-null object
# YEARS         1047 non-null int64
# dtypes: int64(7), object(6)
# memory usage: 106.5+ KB

# %%
breweries_data.isna().sum()
# Out:
# SALES_ID      0
# SALES_REP     0
# EMAILS        0
# BRANDS        0
# PLANT_COST    0
# UNIT_PRICE    0
# QUANTITY      0
# COSTS         0
# PROFIT        0
# COUNTRIES     0
# REGION        0
# MONTHS        0
# YEARS         0
# dtype: int64

# %%
breweries_data.BRANDS.unique()
# Out:
# array(['trophy', 'budweiser', 'castle lite', 'eagle lager', 'hero',
#        'beta malt', 'grand malt'], dtype=object)

# %%
breweries_data["SALES_REP"].unique()
# Out:
# array(['Jardine', 'Gill', 'Sorvino', 'Jones', 'Andrews', 'Thompson',
#        'Morgan', 'Howard', 'Parent', 'Smith', 'Kivell'], dtype=object)

# %%
breweries_data["REGION "].unique()
# Out:
# array(['Southeast', 'west', 'southsouth', 'northwest', 'northeast ',
#        'northcentral '], dtype=object)

# %%
#ANALYSIS OF THE DATA SET

# %%
breweries_data.loc[[70,89,110],:]
# Out:
#      SALES_ID SALES_REP              EMAILS     BRANDS  PLANT_COST  \
# 70      10171    Kivell  kivel_go@yahoo.com     trophy         150
# 89      10190   Andrews      andy@gmail.com  beta malt          80
# 110     10211     Jones   jone.ai@yahoo.com  beta malt          80
#
#      UNIT_PRICE  QUANTITY   COSTS  PROFIT COUNTRIES        REGION     MONTHS  \
# 70          200       948  189600   47400     Ghana     northeast   November
# 89          150       869  130350   60830   Senegal  northcentral       June
# 110         150       848  127200   59360     Ghana     southsouth     March
#
#      YEARS
# 70    2018
# 89    2018
# 110   2019

# %%
breweries_data.iloc[[70,89,110],:]
# Out:
#      SALES_ID SALES_REP              EMAILS     BRANDS  PLANT_COST  \
# 70      10171    Kivell  kivel_go@yahoo.com     trophy         150
# 89      10190   Andrews      andy@gmail.com  beta malt          80
# 110     10211     Jones   jone.ai@yahoo.com  beta malt          80
#
#      UNIT_PRICE  QUANTITY   COSTS  PROFIT COUNTRIES        REGION     MONTHS  \
# 70          200       948  189600   47400     Ghana     northeast   November
# 89          150       869  130350   60830   Senegal  northcentral       June
# 110         150       848  127200   59360     Ghana     southsouth     March
#
#      YEARS
# 70    2018
# 89    2018
# 110   2019

# %%
#Country that generated the highest profit 2019
years = breweries_data[breweries_data.YEARS == 2019]
years.groupby(["COUNTRIES","YEARS"]).agg({"PROFIT":'sum'})
# Out:
#                   PROFIT
# COUNTRIES YEARS
# Benin     2019   5273340
# Ghana     2019   7144070
# Nigeria   2019   4805320
# Senegal   2019   6687560
# Togo      2019   6109960

# %%
#Year with the highest profit
breweries_data.groupby("YEARS").agg({"PROFIT":'sum'})
# Out:
#          PROFIT
# YEARS
# 2017   38503320
# 2018   37063850
# 2019   30020250

# %%
#Month in the three years with the least profit generated
breweries_data.groupby("MONTHS").agg({"PROFIT":'sum'})
# Out:
#             PROFIT
# MONTHS
# April      8573830
# August     8730940
# December   8787290
# February   9028450
# January    8722990
# July       8787010
# June       8828440
# March      9066130
# May        8772250
# November   8820330
# October    8767100
# September  8702660

# %%
#Find out the top two choice of consumer brands in Ghana
Country = breweries_data[breweries_data.COUNTRIES == "Ghana"]
Country.groupby("BRANDS").agg({"QUANTITY":'sum'})
# Out:
#              QUANTITY
# BRANDS
# beta malt       25408
# budweiser       24419
# castle lite     25806
# eagle lager     25829
# grand malt      25615
# hero            25654
# trophy          25524

# %%
breweries_data
# Out:
#       SALES_ID SALES_REP               EMAILS       BRANDS  PLANT_COST  \
# 0        10101   Jardine       jard@gmail.com       trophy         150
# 1        10102      Gill      gillhell@uk.com    budweiser         250
# 2        10103   Sorvino  sorvi2000@gmail.com  castle lite         180
# 3        10104     Jones    jone.ai@yahoo.com  eagle lager         170
# 4        10105   Andrews       andy@gmail.com         hero         150
# ...        ...       ...                  ...          ...         ...
# 1042     11143   Jardine       jard@gmail.com   grand malt          90
# 1043     11144   Jardine       jard@gmail.com       trophy         150
# 1044     11145   Andrews       andy@gmail.com    budweiser         250
# 1045     11146     Jones    jone.ai@yahoo.com  castle lite         180
# 1046     11147    Morgan   morganny@gmail.com  eagle lager         170
#
#       UNIT_PRICE  QUANTITY   COSTS  PROFIT COUNTRIES        REGION     MONTHS  \
# ...

# %%
#Total profit
brewries_profit = breweries_data["PROFIT"].sum()
brewries_profit
# Out:
# 105587420

# %%
breweries_data.MONTHS.unique()
# Out:
# array(['January', 'February', 'March', 'April', 'May', 'June', 'July',
#        'August', 'September', 'October', 'November', 'December'],
#       dtype=object)

# %%
#quantity sold by each sales rep across country
breweries_data.groupby(["COUNTRIES","SALES_REP"]).agg({"QUANTITY":'sum'})
# Out:
#                      QUANTITY
# COUNTRIES SALES_REP
# Benin     Andrews       18383
#           Gill          19748
#           Howard         8016
#           Jardine       22768
#           Jones         30831
#           Kivell        11980
#           Morgan        13606
#           Parent        12499
#           Smith         11086
#           Sorvino       17137
#           Thompson      10270
# Ghana     Andrews       17102
#           Gill          20072
#           Howard         7539
#           Jardine       23107
#           Jones         32160
#           Kivell        11976
#           Morgan        13552
#           Parent        11760
#           Smith         11850
#           Sorvino       18513
#           Thompson      10624
# Nigeria   Andrews       18337
#           Gill          21025
#           Howard         9050
#           Jardine       21958
#           Jones         33104
#           Kivell        11875
#           Morgan        13893
# ...

# %%
#Find out the top two choice of consumer brands in Ghana
Ghana = breweries_data[breweries_data.COUNTRIES == "Ghana"]
Ghana.groupby("BRANDS").agg({"QUANTITY":'sum'})
# Out:
#              QUANTITY
# BRANDS
# beta malt       25408
# budweiser       24419
# castle lite     25806
# eagle lager     25829
# grand malt      25615
# hero            25654
# trophy          25524

# %%
#profit per months
breweries_data.groupby("MONTHS").agg({"PROFIT": 'sum'})
# Out:
#             PROFIT
# MONTHS
# April      8573830
# August     8730940
# December   8787290
# February   9028450
# January    8722990
# July       8787010
# June       8828440
# March      9066130
# May        8772250
# November   8820330
# October    8767100
# September  8702660

# %%
#Country with the highest profit of the fourth quarter in 2019
fourth_quarter = breweries_data[breweries_data.MONTHS == {"October","November","December"}]
fourth_quarter
# Out:
# Empty DataFrame
# Columns: [SALES_ID, SALES_REP, EMAILS, BRANDS, PLANT_COST, UNIT_PRICE, QUANTITY, COSTS, PROFIT, COUNTRIES, REGION , MONTHS, YEARS]
# Index: []

# %%
#country with the highest profit in the fourth quarter in 2019
years_2019 = breweries_data[breweries_data.YEARS == 2019,]
profit_for4th_quarter = years_2019
profit_for4th_quarter
result = profit_for4th_quarter
result[(result["MONTHS"]== "October")
|(result["MONTHS"]== "November")|
(result["MONTHS"] == "December")]
result
# Out:
#       SALES_ID SALES_REP               EMAILS       BRANDS  PLANT_COST  \
# 0        10101   Jardine       jard@gmail.com       trophy         150
# 5        10106   Jardine       jard@gmail.com    beta malt          80
# 8        10109    Morgan   morganny@gmail.com    budweiser         250
# 11       10112     Jones    jone.ai@yahoo.com         hero         150
# 15       10116     Jones    jone.ai@yahoo.com    budweiser         250
# ...        ...       ...                  ...          ...         ...
# 1035     11136    Morgan   morganny@gmail.com   grand malt          90
# 1037     11138   Sorvino  sorvi2000@gmail.com    budweiser         250
# 1040     11141  Thompson         thomp@uk.com         hero         150
# 1044     11145   Andrews       andy@gmail.com    budweiser         250
# 1046     11147    Morgan   morganny@gmail.com  eagle lager         170
#
#       UNIT_PRICE  QUANTITY   COSTS  PROFIT COUNTRIES        REGION   \
# ...

# %%
#Country with the highest profit of the fourth quarter in 2019
year_2019 = breweries_data[breweries_data.YEARS == 2019]
year_2019[(year_2019["MONTHS"] == "October")
|(year_2019["MONTHS"]== "November")|
(year_2019["MONTHS"]== "December")]
# Out:
#       SALES_ID SALES_REP                    EMAILS       BRANDS  PLANT_COST  \
# 11       10112     Jones         jone.ai@yahoo.com         hero         150
# 81       10182   Andrews            andy@gmail.com         hero         150
# 94       10195      Gill           gillhell@uk.com  eagle lager         170
# 106      10207     Jones         jone.ai@yahoo.com    budweiser         250
# 118      10219     Jones         jone.ai@yahoo.com   grand malt          90
# ...        ...       ...                       ...          ...         ...
# 959      11060    Parent           parentty@uk.com       trophy         150
# 982      11083    Parent           parentty@uk.com  castle lite         180
# 993      11094     Jones         jone.ai@yahoo.com   grand malt          90
# 1017     11118     Jones         jone.ai@yahoo.com  castle lite         180
# 1030     11131    Howard  howard_freeman@yahoo.com    budweiser         250
#
# ...

# %%
breweries_data.MONTHS.unique()
# Out:
# array(['January', 'February', 'March', 'April', 'May', 'June', 'July',
#        'August', 'September', 'October', 'November', 'December'],
#       dtype=object)

# %%
#Profit generated by each sales_rep
sns.countplot(y= "SALES_REP", data = breweries_data, hue_order = "PROFIT",orient = "p", saturation = 90)

# %%
#profit across years
sns.boxenplot(x= "YEARS",y ="PROFIT", hue= "YEARS", data= breweries_data,outlier_prop = 0.02, orient = "V", dodge = 1)

# %%
#country with the highest consumptionof beers
plt.figure(figsize=(7,5))
sns.pointplot(x = "COUNTRIES", y = "QUANTITY", data= breweries_data, palette = "viridis")

# %%
sns.violinplot(x= "REGION ", y = "PROFIT", data = breweries_data,palette = "tab10",gridsize =10, figsize = 20)

# %%
#Region analysis

plt.figure(figsize=(15,10))
plt.subplot(2,3,1)
plt.xticks(rotation = 30)
sns.violinplot(x= "REGION ", y = "PROFIT", data = breweries_data,palette = "tab10",gridsize = 30,figsize = 30)


plt.subplot(2,3,2)
plt.xticks(rotation = 30)
sns.violinplot(x = "REGION ", y ="PLANT_COST", data = breweries_data, gridsize = 30, figsize = 30)


plt.subplot(2,3,3)
plt.xticks(rotation = 30)
sns.violinplot(x ="REGION ", y = "COSTS", data = breweries_data,palette = "PuBuGn", gridsize = 30, figsize = 30 )
plt.ylabel(' ')
plt.yticks([ ])

plt.subplot(2,3,4)
plt.xticks(rotation = 30)
sns.violinplot(x= "REGION ",y =  "QUANTITY", data = breweries_data, palette = "summer", gridsize = 30, figsize = 30)
plt.ylabel(' ')
plt.yticks([ ])

plt.subplot(2,3,5)
plt.xticks(rotation = 30)
sns.violinplot(x= "REGION ",y =  "UNIT_PRICE", data = breweries_data, palette = "summer", gridsize = 30, figsize = 30)
plt.ylabel(' ')
plt.yticks([ ])
# Out:
# ([], <a list of 0 Text yticklabel objects>)

# %%
breweries_data
# Out:
#       SALES_ID SALES_REP               EMAILS       BRANDS  PLANT_COST  \
# 0        10101   Jardine       jard@gmail.com       trophy         150
# 1        10102      Gill      gillhell@uk.com    budweiser         250
# 2        10103   Sorvino  sorvi2000@gmail.com  castle lite         180
# 3        10104     Jones    jone.ai@yahoo.com  eagle lager         170
# 4        10105   Andrews       andy@gmail.com         hero         150
# ...        ...       ...                  ...          ...         ...
# 1042     11143   Jardine       jard@gmail.com   grand malt          90
# 1043     11144   Jardine       jard@gmail.com       trophy         150
# 1044     11145   Andrews       andy@gmail.com    budweiser         250
# 1045     11146     Jones    jone.ai@yahoo.com  castle lite         180
# 1046     11147    Morgan   morganny@gmail.com  eagle lager         170
#
#       UNIT_PRICE  QUANTITY   COSTS  PROFIT COUNTRIES        REGION     MONTHS  \
# ...
